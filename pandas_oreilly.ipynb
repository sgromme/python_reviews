# %% [markdown]
# Series

# %%
import pandas as pd

# %%
ser = pd.Series(range(40))

# %%
dir(ser)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %% [markdown]
# Series 2

# %% [markdown]
# Broadcasting

# %%
l = [23, 33, 12, 67]

ser2 = pd.Series(l)

# %%
ser2
# Out:
# 0    23
# 1    33
# 2    12
# 3    67
# dtype: int64

# %%
ser2 +5
# Out:
# 0    28
# 1    38
# 2    17
# 3    72
# dtype: int64

# %%
temp2 = pd.Series(data=(33, 44, 12, 55), index=['M','T','W','Th'])
temp2.describe()
# Out:
# count     4.000000
# mean     36.000000
# std      18.348479
# min      12.000000
# 25%      27.750000
# 50%      38.500000
# 75%      46.750000
# max      55.000000
# dtype: float64

# %%
temp2.plot()
# Out:
# <Axes: >

# %%
temp2.plot.bar()
# Out:
# <Axes: >

# %%
testdict = {'name':['Bob', 'Jim', 'Scott'], 'age':[34, 22, 66]}


testdb = pd.DataFrame(testdict)

# %%
testdb.describe()
# Out:
#              age
# count   3.000000
# mean   40.666667
# std    22.744963
# min    22.000000
# 25%    28.000000
# 50%    34.000000
# 75%    50.000000
# max    66.000000

# %%
testdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
testdb
# Out:
#     name  age
# 0    Bob   34
# 1    Jim   22
# 2  Scott   66

# %%
testdb.query('name =="Jim" and age > 20')
# Out:
#   name  age
# 1  Jim   22
